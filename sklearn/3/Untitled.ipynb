# %%
import numpy as np
from sklearn.decomposition import PCA

# 创建二维数组X
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])

# 创建主成分分析对象pca，保留2个主成分
pca = PCA(n_components=2)
pca.fit(X)

# 打印所保留的2个成分各自的方差百分比
print(pca.explained_variance_ratio_)

# 创建主成分分析对象pca，使用MLE算法计算降维后维度数量
pca = PCA(n_components='mle')
pca.fit(X)
# Out:
# [0.99244289 0.00755711]
# [7.93954312]
# [0.99244289]
# 1
# [0.99244289 0.00755711]
# [[2.09783018 0.30560234]
#  [2.13443044 2.13171694]]

# %%
# 打印各维度的方差
print(pca.explained_variance_)

# 打印各维度的方差值占总方差值的比例
print(pca.explained_variance_ratio_)

# 打印降维后的维度数量
print(pca.n_components_)

# 创建主成分分析对象pca，保留2个主成分，指定奇异值分解SVD的方法为'full'
pca = PCA(n_components=2, svd_solver='full')
pca.fit(X)

# 打印所保留的2个成分各自的方差百分比
print(pca.explained_variance_ratio_)
# Out:
# [3.501836 0.014164]
# [0.99597156 0.00402844]
# 2
# [0.81968748 0.18031252]

# %%
# 创建二维数组X
X = np.array([[1, 1], [2, 1], [3, 1.2], [4, 1], [5, 0.8], [6, 1]])

# 导入NMF类，进行非负矩阵因子分解
from sklearn.decomposition import NMF
model = NMF(n_components=2, init='random', random_state=0)
model.fit_transform(X)

# 查看分解后数据的因子数量
print(model.components_)
# Out:
# [[2.09783018 0.30560234]
#  [2.13443044 2.13171694]]

# %%
# 导入KernelPCA类和make_moons函数，创建训练数据
from sklearn.decomposition import KernelPCA
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, random_state=123)

# 创建核主成分分析对象，进行核主成分分析
scikit_kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
kpca_X = scikit_kpca.fit_transform(X)

# %%
# 绘制训练数据和核主成分分析返回数据的散点图
import matplotlib.pyplot as plt
# %matplotlib inline
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax1.scatter(X[y==0,0], X[y==0,1], color='red', marker='^', alpha=0.5)
ax1.scatter(X[y==1,0], X[y==1,1], color='blue', marker='o', alpha=0.5)
ax1.set_xlabel('PC1')
ax1.set_ylabel('PC2')
ax2 = fig.add_subplot(212)
ax2.scatter(kpca_X[y==0,0], kpca_X[y==0,1], color='red', marker='^', alpha=0.5)
ax2.scatter(kpca_X[y==1,0], kpca_X[y==1,1], color='green', marker='*', alpha=0.5)
ax2.set_xlabel('PC1 of KPCA')
ax2.set_ylabel('PC2 of KPCA')
plt.show()
